# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=[11,10,12,14,12,15,14, 13, 15, 102, 12, 14, 17, 19, 107, 10, 13, 12, 14, 12, 108, 12, 11, 14, 13, 15, 10, 15, 12, 10, 14, 13, 15, 10]
print(dataset)
# Out:
# [11, 10, 12, 14, 12, 15, 14, 13, 15, 102, 12, 14, 17, 19, 107, 10, 13, 12, 14, 12, 108, 12, 11, 14, 13, 15, 10, 15, 12, 10, 14, 13, 15, 10]

# %%
sns.histplot(dataset, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.boxplot(dataset)
# Out:
# <Axes: >

# %%
import statistics as stat

mean=stat.mean(dataset)
std=stat.stdev(dataset)
# threshold=3
outlier=[]
for i in dataset:
    x=mean+3*std
    if i>x:
        outlier.append(i)
print(outlier)
# Out:
# [102, 107, 108]

# %%
mean+3*std
# Out:
# 101.4831687858394

# %%
def find_outliers(mean,std,dataset):
    outlier=[]
    for i in dataset:
        x=mean+3*std
        if i>x:
            outlier.append(i)
print(outlier)
# Out:
# [102, 107, 108]

# %%
dataset
# Out:
# [11,
#  10,
#  12,
#  14,
#  12,
#  15,
#  14,
#  13,
#  15,
#  102,
#  12,
#  14,
#  17,
#  19,
#  107,
#  10,
#  13,
#  12,
#  14,
#  12,
#  108,
#  12,
#  11,
#  14,
#  13,
#  15,
#  10,
#  15,
#  12,
#  10,
#  14,
#  13,
#  15,
#  10]

# %%
new_data = [x for x in dataset if (x not in outlier)]

# %%
new_data
# Out:
# [11,
#  10,
#  12,
#  14,
#  12,
#  15,
#  14,
#  13,
#  15,
#  12,
#  14,
#  17,
#  19,
#  10,
#  13,
#  12,
#  14,
#  12,
#  12,
#  11,
#  14,
#  13,
#  15,
#  10,
#  15,
#  12,
#  10,
#  14,
#  13,
#  15,
#  10]

# %%
dataset.remove(i) for i 
# outlier

# %%
print(dataset)
sns.boxplot(new_data)
# Out:
# [11, 10, 12, 14, 12, 15, 14, 13, 15, 102, 12, 14, 17, 19, 107, 10, 13, 12, 14, 12, 108, 12, 11, 14, 13, 15, 10, 15, 12, 10, 14, 13, 15, 10]
# <Axes: >

# %%
dataset_sorted=sorted(dataset)
q1=(len(dataset_sorted)+1)/4
print(q1)
# Out:
# 8.75
