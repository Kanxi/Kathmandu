# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# plt.figure(figsize=(6,6))
data=[2,2,3,4,5,5,5,6,7,8,8,8,8,8,9,9,10,11,11,12,16]
sns.boxplot(data)
plt.xlabel('Data')
plt.ylabel('Values')
plt.title('Boxplot of Data Point')
plt.show()
